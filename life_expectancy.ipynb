# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('life.csv')

# %%
dataset=dataset.drop(['Country','Status'],axis=True)

# %%
dataset.isnull()
# Out:
#        Year  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0     False             False            False          False    False
# 1     False             False            False          False    False
# 2     False             False            False          False    False
# 3     False             False            False          False    False
# 4     False             False            False          False    False
# ...     ...               ...              ...            ...      ...
# 2933  False             False            False          False    False
# 2934  False             False            False          False    False
# 2935  False             False            False          False    False
# 2936  False             False            False          False    False
# 2937  False             False            False          False    False
#
#       percentage expenditure  Hepatitis B  Measles    BMI   \
# ...

# %%
dataset.isnull().sum()
# Out:
# Year                                 0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             2938 non-null   int64
#  1   Life expectancy                  2928 non-null   float64
#  2   Adult Mortality                  2928 non-null   float64
#  3   infant deaths                    2938 non-null   int64
#  4   Alcohol                          2744 non-null   float64
#  5   percentage expenditure           2938 non-null   float64
#  6   Hepatitis B                      2385 non-null   float64
#  7   Measles                          2938 non-null   int64
#  8    BMI                             2904 non-null   float64
#  9   under-five deaths                2938 non-null   int64
#  10  Polio                            2919 non-null   float64
#  11  Total expenditure                2712 non-null   float64
# ...

# %%
dataset.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
num_cols = dataset.select_dtypes(include=['float64', 'int64']).columns
dataset[num_cols] = dataset[num_cols].fillna(dataset[num_cols].median())

# Drop rows with missing values in categorical columns
dataset.dropna(inplace=True)

# Verify missing values again
dataset.isnull().sum()
# Out:
# Year                               0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
datasetcr = dataset.corr()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(datasetcr,annot=True, fmt=".2f",cmap='coolwarm', vmin=-1,vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %%
dataset=dataset.drop(['Adult Mortality','infant deaths', 'Measles ', 'under-five deaths ', 'Population', ' HIV/AIDS',' thinness  1-19 years',' thinness 5-9 years'],axis=True)

# %%
sns.pairplot(dataset)

# %%
x = dataset.drop(['Life expectancy '],axis=True)
y = dataset['Life expectancy ']

# %%
x.isnull().sum()
# Out:
# Year                               0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
#  BMI                               0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
# GDP                                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
x
# Out:
# array([[ 1.6217623 , -1.15698891, -0.33557031, ..., -0.45337072,
#         -0.73797341, -0.58501698],
#        [ 1.40498625, -1.15698891, -0.33444132, ..., -0.45123167,
#         -0.75260009, -0.61564876],
#        [ 1.1882102 , -1.15698891, -0.33459444, ..., -0.44979884,
#         -0.78185344, -0.64628054],
#        ...,
#        [-1.19632639, -0.02980544, -0.37143289, ..., -0.49300494,
#         -0.99150247, -0.61564876],
#        [-1.41310244, -0.72090662, -0.37143289, ..., -0.45605396,
#         -0.99150247, -0.67691233],
#        [-1.62987849, -0.73110738, -0.37143289, ..., -0.45614636,
#         -0.95737356, -0.67691233]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((2350, 11), (588, 11), (2350,), (588,))

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test).round(1)

# %%
y_test
# Out:
# 2546    73.7
# 650     75.9
# 1740    74.2
# 177     76.8
# 1377    51.9
#         ...
# 859     59.7
# 1405    73.5
# 962     61.1
# 2658    69.6
# 2272    74.0
# Name: Life expectancy , Length: 588, dtype: float64

# %%
y_pred = regressor.predict(x_test).round(1)

# %%
y_pred
# Out:
# array([65.3, 75.9, 76.1, 78. , 57.9, 52.3, 61.4, 68.2, 74.3, 64.3, 56.3,
#        68.6, 59.7, 68.5, 71.3, 62.5, 53. , 80.8, 69.1, 82. , 81.3, 85.4,
#        70.6, 68.9, 68.3, 69.6, 63.3, 58.8, 75. , 71.6, 62.7, 72.4, 63.7,
#        68.3, 80.8, 57.7, 63.4, 74.1, 57.8, 75. , 59.9, 65.5, 76.3, 78.5,
#        77. , 54.8, 78.1, 68.2, 60.8, 65.5, 59.8, 53.8, 79. , 69.2, 73.1,
#        63.7, 73.4, 67.1, 60.6, 64.6, 73.5, 56.3, 74.2, 68.1, 51.6, 70.1,
#        55. , 77.3, 59. , 73.2, 82.4, 75.2, 74.8, 63.7, 56.1, 71.8, 63.8,
#        76.8, 54.6, 57.3, 63.1, 60.7, 68.3, 62.8, 51.5, 70.7, 74.4, 67.2,
#        77.8, 73.8, 72.8, 61.3, 72.5, 76.6, 74.8, 65.9, 77. , 71.9, 65.3,
#        60.1, 84.8, 57.5, 69.5, 53.3, 70.6, 76.3, 71.4, 63.7, 60.2, 65.8,
#        69.4, 58.9, 66.2, 64.4, 62.5, 75.2, 62.2, 56.9, 67.1, 63.6, 58.8,
#        73.1, 79.6, 57.7, 58.9, 64.6, 71.6, 67.7, 73.7, 71.7, 75.3, 83.4,
#        54. , 69.8, 50.7, 71.2, 76.2, 74.8, 76.9, 75.4, 68.7, 64. , 60.3,
# ...

# %%
calculation = pd.DataFrame(np.c_[y_test,y_pred], columns = ["Original life expectancy","Predict life expectancy"])
calculation.head(10)
# Out:
#    Original life expectancy  Predict life expectancy
# 0                      73.7                     65.3
# 1                      75.9                     75.9
# 2                      74.2                     76.1
# 3                      76.8                     78.0
# 4                      51.9                     57.9
# 5                      49.6                     52.3
# 6                      67.4                     61.4
# 7                      73.9                     68.2
# 8                      77.2                     74.3
# 9                      55.0                     64.3

# %%
print("Training Accuracy :", regressor.score(x_train, y_train))
print("Testing Accuracy :", regressor.score(x_test, y_test))
# Out:
# Training Accuracy : 0.6291984831450075
# Testing Accuracy : 0.6727824073454317
